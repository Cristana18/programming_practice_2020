# %% [markdown]
# <a href="https://colab.research.google.com/github/Cristana18/programming_practice_2020/blob/master/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Упражнение 1. Запишите выражение, заданное формулой, в виде, подходящем для языка Python.

# %%
import math
x = float(input('Введите номер ....'))
a = math.sin(x) + 1
b = (5/4) + (x*5)
y = math.log1p(x) + x**2*((math.e**a)/b)
# Out:
# Введите номер ....1
# 2

# %%
import math
x = float(input('Введите номер ....'))
y = math.log1p(x) + x**2**((math.e**(math.sin(x) + 1))/((5/4) + (x*5)))

# %% [markdown]
# Упражнение 2

# %%
from matplotlib import pyplot
# Квадратная функция.
def f1(x):
    return (x**2)-x-6

# Значения по оси X, взятые на графике.
x = range(-10, 15)

# Постройте график обеих функций.
pyplot.plot(x, [f1(i) for i in x])

# Установите цвет осей.
pyplot.axhline(0, color="black")
pyplot.axvline(0, color="black")

# Предельные значения оси.
pyplot.xlim(-10, 10)
pyplot.ylim(-10, 10)

 math.log10(1 + tan(1 / 1 + math.sin**2(x))*(x**2 + 1)*math.exp(x / 10)
# Out:
# (-10.0, 10.0)

# %% [markdown]
# Упражнения 3

# %%
import math 
import matplotlib.pyplot as plt
def f1(x):
    return math.log( x*2 +1 [a] )*b
x = float(input('Введите номер ....')) 
a = 1 + math.tan(1 / 1 + math.sin*2(x)
b = math.exp(math.fabs(-x)/ 10)
#log(x,[base])
y = math.log( x*2 +1 [a] )*b
return y
 
# Значения по оси X, взятые на графике.
x = range(-10, 15)

# Постройте график обеих функций.
pyplot.plot(x, [f1(i) for i in x])

# Установите цвет осей.
pyplot.axhline(0, color="black")
pyplot.axvline(0, color="black")

# Предельные значения оси.
pyplot.xlim(-10, 10)
pyplot.ylim(-10, 10)
# Out:
#   File "<ipython-input-7-1cf5bd3c1454>", line 7
#     b = math.exp(math.fabs(-x)/ 10)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Упражнения 4

# %%
with plt.xkcd():
    plt.pie([70, 10, 10, 10], labels=('В комментариях', 'В Ираке', 'В Сирии', 'В Афганистане'))
    plt.title('Где ведутся самые ожесточенные бои')

# %% [markdown]
# eval()

# %%
# Perimeter of Square
def calculatePerimeter(l):
    return 4*l

# Area of Square
def calculateArea(l):
    return l*l

expression = input("Type a function: ")

for l in range(1, 5):
    if (expression == 'calculatePerimeter(l)'):
        print("If length is ", l, ", Perimeter = ", eval(expression))
    elif (expression == 'calculateArea(l)'):
        print("If length is ", l, ", Area = ", eval(expression))
    else:
        print('Wrong Function')
        break

# %% [markdown]
# plt.xkcd()

# %%
import math
import numpy as np
from matplotlib import pyplot as plt
plt.xkcd()
plt.pie ([70, 10, 10, 10], labels = ('En comentarios', 'En Irak', 'En Siria', 'En Afganistán'))
plt.title ('Donde tienen lugar las batallas más feroces')
# Out:
# Text(0.5, 1.0, 'Donde tienen lugar las batallas más feroces')
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 225 missing from current font.
#   font.set_text(s, 0.0, flags=flags)

# %%
# Часть 1 список со значениями для X
func = input('Введите желаемую функцию:') # devuelve str
ЗНАЧЕНИЕ = []
итерации = int(input('введите, сколько значений вы хотите для x: '))
for i in range(итерации):
  print('ЗНАЧЕНИЕ', i+1)
  x = float(input('Введите значение X: '))
  ЗНАЧЕНИЕ.append(x)
print(ЗНАЧЕНИЕ)
# Out:
# Введите желаемую функцию:x
# введите, сколько значений вы хотите для x: 4
# ЗНАЧЕНИЕ 1
# Введите значение X: 1
# ЗНАЧЕНИЕ 2
# Введите значение X: 2
# ЗНАЧЕНИЕ 3
# Введите значение X: 3
# ЗНАЧЕНИЕ 4
# Введите значение X: 4
# [1.0, 2.0, 3.0, 4.0]

# %%
#Оценить заданную функцию для каждой точки X

# %%
#График
import pylab
import numpy
from mpl_toolkits.mplot3d import Axes3D

def func1 (x):
    return 2 * x + 1


pylab.xkcd()
fig = pylab.subplot (2, 2, 2)
# Данные для построения графика
data = [70, 10, 10, 10]

# Нарисовать круговой график
pylab.pie (data)

pylab.show()

# %% [markdown]
# Упражнение 5. Приблизить данные из приведённого примера с погрешностями или свои собственные (из лабораторного практикума по общей физике) многочленами первой и второй степени. Начертить точки с погрешностями и полученные аппроксимационные кривые на одном графике.

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [0.48, 0.81, 0.156, 0.182, 0.535]
plt.errorbar(x, y, xerr=0.05, yerr=0.1)
plt.grid()
plt.show()

# %% [markdown]
# Упражнение 6. Постройте график функции Вейерштрасса

# %%
from math import cos
from matplotlib import pyplot as plt
from matplotlib.ticker import FuncFormatter
from pylab import rcParams
step = 0.0001  # the smaller the more precise the plot is
a = 0.5
b = 15
n = 100
intervalBegin = 0
intervalEnd = 1
data = []
for x in range(int((1 / step) * abs(intervalEnd - intervalBegin))):
    output = 0
    for i in range(n):
        output += pow(a, i) * cos(pow(b, i) * i * x * step)
    data.append(output)
rcParams['figure.figsize'] = 10, 9
plt.gca().xaxis.grid(True)
plt.gca().yaxis.grid(True)
plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(x * step, ',')))
plt.plot(data)
plt.show()
