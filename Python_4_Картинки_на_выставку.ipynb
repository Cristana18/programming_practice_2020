# %% [markdown]
# Задание №1 Нарисовать злой смайлик:

# %%
import turtle
t = turtle.Pen()
t.shape('turtle')
t.color('black')
t.up()
t.goto(100, 0)
t.left(90)
t.down()
t.fillcolor('yellow')
t.begin_fill()
t.circle(100)
t.end_fill()
t.up()
t.goto(-30, 50)
t.down()
t.fillcolor('red')
t.begin_fill()
t.circle(15)
t.end_fill()
t.up()
t.goto(60, 50)
t.down()
t.fillcolor('red')
t.begin_fill()
t.circle(15)
t.end_fill()

t.up()
t.goto(-35, 50)
t.down()
t.fillcolor('black')
t.begin_fill()
t.circle(10)
t.end_fill()
t.up()
t.goto(55, 50)
t.down()

t.fillcolor('black')
t.begin_fill()
t.circle(10)
t.end_fill()
t.up()
t.goto(0, 30)
t.down()

t.color('black')
t.pensize(8)
t.left(180)
t.forward(25)

t.up()
t.goto(-50, -20)
t.color('black')
t.begin_fill()
t.pensize(5)
t.down()
t.forward(50)

t.left(90)
t.forward(100)
t.left(90)
t.forward(50)
t.left(90)
t.forward(100)
t.end_fill()

t.up()
t.goto(-30, 50)
t.color('black')
t.begin_fill()
t.pensize(2)
t.down()
t.left(-120)
t.forward(25)
t.left(90)
t.forward(100)
t.left(90)
t.forward(25)
t.left(90)
t.forward(100)
t.end_fill()

t.up()
t.goto(30, 60)
t.color('black')
t.begin_fill()
t.pensize(2)
t.down()
t.left(0)
t.forward(25)
t.left(90)
t.forward(100)
t.left(90)
t.forward(25)
t.left(90)
t.forward(100)
t.end_fill()

# %% [markdown]
# Задание №2

# %%
import turtle
import random

window = turtle.Screen()
window.bgcolor("black")

random_colors = ["#0ca90c", "#c20d0d", "#ffffff", "#ffd700", "#3225de", "#8314b9"]

tortuga = turtle.Turtle()
tortuga.speed(0)
tortuga.left(90)

def рисоватьДерево(размерВетки, tortuga):
    tortuga.pensize(размерВетки/10)
    if (размерВетки < 40):
        tortuga.dot(random.randint(7, 10), random.choice(random_colors))
        return
    tortuga.forward(размерВетки)
    tortuga.left(30)
    рисоватьДерево(размерВетки*random.uniform(0.8, 0.9), tortuga)
    tortuga.right(60)
    рисоватьДерево(размерВетки*random.uniform(0.8, 0.9), tortuga)
    tortuga.left(30)
    tortuga.backward(размерВетки)

tortuga.penup()
tortuga.setpos(0, -250)
tortuga.pendown()
tortuga.color("#406c35")
рисоватьДерево(100, tortuga)


window.exitonclick()

# %% [markdown]
# Задание №3

# %%
import turtle
import random

window = turtle.Screen()
window.bgcolor("black")

random_colors = ["#0ca90c", "#c20d0d", "#ffffff", "#ffd700", "#3225de", "#8314b9"]

tortuga = turtle.Turtle()
tortuga.speed(0)
tortuga.left(90)

def рисоватьДерево(размерВетки, tortuga):
    tortuga.pensize(размерВетки/10)
    if (размерВетки < 40):
        tortuga.dot(random.randint(7, 10), random.choice(random_colors))
        return
    tortuga.forward(размерВетки)
    tortuga.left(30)
    рисоватьДерево(размерВетки*random.uniform(0.8, 0.9), tortuga)
    tortuga.right(60)
    рисоватьДерево(размерВетки*random.uniform(0.8, 0.9), tortuga)
    tortuga.left(30)
    tortuga.backward(размерВетки)

tortuga.penup()
tortuga.setpos(0, -250)
tortuga.pendown()
tortuga.color("#406c35")
рисоватьДерево(100, tortuga)

tortuga.penup()
tortuga.setpos(-60, 150)
tortuga.pendown()
tortuga.color("yellow")
tortuga.begin_fill()
for i in range(5): # 5-конечная звезда
    tortuga.forward(150)
    tortuga.right(144)
tortuga.end_fill()

# рождественские огни
maxY = 250
maxX = 350
рождественскиеОгни = []

for j in range(0, 10000):
    y = random.randint(-1*maxY, maxX)
    x = random.randint(-1*maxX, maxY)
    luz = turtle.Turtle()
    luz.speed(0)
    luz.hideturtle()
    luz.penup()
    luz.setpos(x, y)
    luz.pendown()
    luz.dot(random.randint(1, 5), random.choice(random_colors))
    рождественскиеОгни.append(luz)
    if len(рождественскиеОгни) > 150:
        luzAApagar = random.choice(рождественскиеОгни)
        luzAApagar.clear()


window.exitonclick()
